# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('developer_survey_2017/survey_results_public.csv')
df_schema = pd.read_csv('developer_survey_2017/survey_results_schema.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree
#
#                                   MajorUndergrad  \
# 0                                            NaN
# 1       Computer science or software engineering
# 2       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
# 4       Computer science or software engineering
#
#                                           HomeRemote  \
# 0                                                NaN
# 1              More than half, but not all, the time
# 2  Less than half the time, but at least one day ...
# 3  Less than half the time, but at least one day ...
# 4                                              Never
#
#                 CompanySize  ... StackOverflowMakeMoney Gender  \
# 0                       NaN  ...      Strongly disagree   Male
# 1        20 to 99 employees  ...      Strongly disagree   Male
# 2  10,000 or more employees  ...               Disagree   Male
# 3  10,000 or more employees  ...               Disagree   Male
# 4        10 to 19 employees  ...                    NaN    NaN
#
#   HighestEducationParents                          Race         SurveyLong  \
# 0             High school  White or of European descent  Strongly disagree
# 1       A master's degree  White or of European descent     Somewhat agree
# 2   A professional degree  White or of European descent     Somewhat agree
# 3       A doctoral degree  White or of European descent              Agree
# 4                     NaN                           NaN                NaN
#
#   QuestionsInteresting QuestionsConfusing InterestedAnswers    Salary  \
# 0       Strongly agree           Disagree    Strongly agree       NaN
# 1       Somewhat agree           Disagree    Strongly agree       NaN
# 2                Agree           Disagree             Agree  113750.0
# 3                Agree     Somewhat agree    Strongly agree       NaN
# 4                  NaN                NaN               NaN       NaN
#
#    ExpectedSalary
# 0             NaN
# 1         37500.0
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 154 columns]

# %%
df20 = pd.read_csv('developer_survey_2020/survey_results_public.csv')
df20_schema = pd.read_csv('developer_survey_2020/survey_results_schema.csv')
df20.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 0   European Euro  ...  Neither easy nor difficult  Appropriate in length
# 1  Pound sterling  ...                         NaN                    NaN
# 2             NaN  ...  Neither easy nor difficult  Appropriate in length
# 3    Albanian lek  ...                         NaN                    NaN
# 4             NaN  ...                        Easy              Too short
#
#   Trans                                     UndergradMajor  \
# 0    No  Computer science, computer engineering, or sof...
# 1   NaN  Computer science, computer engineering, or sof...
# 2   NaN                                                NaN
# 3    No  Computer science, computer engineering, or sof...
# 4    No  Computer science, computer engineering, or sof...
#
#   WebframeDesireNextYear    WebframeWorkedWith  \
# 0           ASP.NET Core  ASP.NET;ASP.NET Core
# 1                    NaN                   NaN
# 2                    NaN                   NaN
# 3                    NaN                   NaN
# 4   Django;Ruby on Rails         Ruby on Rails
#
#                               WelcomeChange WorkWeekHrs YearsCode YearsCodePro
# 0   Just as welcome now as I felt last year        50.0        36           27
# 1  Somewhat more welcome now than last year         NaN         7            4
# 2  Somewhat more welcome now than last year         NaN         4          NaN
# 3  Somewhat less welcome now than last year        40.0         7            4
# 4   Just as welcome now as I felt last year         NaN        15            8
#
# [5 rows x 61 columns]

# %%
df.describe()

# %%
df_schema.Column.unique()
# Out:
# array(['Respondent', 'Professional', 'ProgramHobby', 'Country',
#        'University', 'EmploymentStatus', 'FormalEducation',
#        'MajorUndergrad', 'HomeRemote', 'CompanySize', 'CompanyType',
#        'YearsProgram', 'YearsCodedJob', 'YearsCodedJobPast',
#        'DeveloperType', 'WebDeveloperType', 'MobileDeveloperType',
#        'NonDeveloperType', 'CareerSatisfaction', 'JobSatisfaction',
#        'ExCoderReturn', 'ExCoderNotForMe', 'ExCoderBalance',
#        'ExCoder10Years', 'ExCoderBelonged', 'ExCoderSkills',
#        'ExCoderWillNotCode', 'ExCoderActive', 'PronounceGIF',
#        'ProblemSolving', 'BuildingThings', 'LearningNewTech',
#        'BoringDetails', 'JobSecurity', 'DiversityImportant', 'AnnoyingUI',
#        'FriendsDevelopers', 'RightWrongWay', 'UnderstandComputers',
#        'SeriousWork', 'InvestTimeTools', 'WorkPayCare',
#        'KinshipDevelopers', 'ChallengeMyself', 'CompetePeers',
#        'ChangeWorld', 'JobSeekingStatus', 'HoursPerWeek', 'LastNewJob',
#        'AssessJobIndustry', 'AssessJobRole', 'AssessJobExp',
#        'AssessJobDept', 'AssessJobTech', 'AssessJobProjects',
#        'AssessJobCompensation', 'AssessJobOffice', 'AssessJobCommute',
#        'AssessJobRemote', 'AssessJobLeaders', 'AssessJobProfDevel',
#        'AssessJobDiversity', 'AssessJobProduct', 'AssessJobFinances',
#        'ImportantBenefits', 'ClickyKeys', 'JobProfile', 'ResumePrompted',
#        'LearnedHiring', 'ImportantHiringAlgorithms',
#        'ImportantHiringTechExp', 'ImportantHiringCommunication',
#        'ImportantHiringOpenSource', 'ImportantHiringPMExp',
#        'ImportantHiringCompanies', 'ImportantHiringTitles',
#        'ImportantHiringEducation', 'ImportantHiringRep',
#        'ImportantHiringGettingThingsDone', 'Currency', 'Overpaid',
#        'TabsSpaces', 'EducationImportant', 'EducationTypes',
#        'SelfTaughtTypes', 'TimeAfterBootcamp', 'CousinEducation',
#        'WorkStart', 'HaveWorkedLanguage', 'WantWorkLanguage',
#        'HaveWorkedFramework', 'WantWorkFramework', 'HaveWorkedDatabase',
#        'WantWorkDatabase', 'HaveWorkedPlatform', 'WantWorkPlatform',
#        'IDE', 'AuditoryEnvironment', 'Methodology', 'VersionControl',
#        'CheckInCode', 'ShipIt', 'OtherPeoplesCode', 'ProjectManagement',
#        'EnjoyDebugging', 'InTheZone', 'DifficultCommunication',
#        'CollaborateRemote', 'MetricAssess', 'EquipmentSatisfiedMonitors',
#        'EquipmentSatisfiedCPU', 'EquipmentSatisfiedRAM',
#        'EquipmentSatisfiedStorage', 'EquipmentSatisfiedRW',
#        'InfluenceInternet', 'InfluenceWorkstation', 'InfluenceHardware',
#        'InfluenceServers', 'InfluenceTechStack', 'InfluenceDeptTech',
#        'InfluenceVizTools', 'InfluenceDatabase', 'InfluenceCloud',
#        'InfluenceConsultants', 'InfluenceRecruitment',
#        'InfluenceCommunication', 'StackOverflowDescribes',
#        'StackOverflowSatisfaction', 'StackOverflowDevices',
#        'StackOverflowFoundAnswer', 'StackOverflowCopiedCode',
#        'StackOverflowJobListing', 'StackOverflowCompanyPage',
#        'StackOverflowJobSearch', 'StackOverflowNewQuestion',
#        'StackOverflowAnswer', 'StackOverflowMetaChat',
#        'StackOverflowAdsRelevant', 'StackOverflowAdsDistracting',
#        'StackOverflowModeration', 'StackOverflowCommunity',
#        'StackOverflowHelpful', 'StackOverflowBetter',
#        'StackOverflowWhatDo', 'StackOverflowMakeMoney', 'Gender',
#        'HighestEducationParents', 'Race', 'SurveyLong',
#        'QuestionsInteresting', 'QuestionsConfusing', 'InterestedAnswers',
#        'Salary', 'ExpectedSalary'], dtype=object)

# %%
'''from collections import Counter
developerType = []
temp = df.DeveloperType.drop(df.loc[df.DeveloperType.isnull()].index)
for i in temp:
    if i is not None:
        types = i.replace(' ', '').split(";")
        developerType.extend(types)
print(Counter(developerType))
dev_type_df = df['DeveloperType'].str.get_dummies(sep=';')
dev_type_df.head()'''

# %%
'''
from the plot it appears that some types are duplicated which could be related to extra space int he value so 
we need to eliminate those cases to get a better view
''' 
#df.DeveloperType = df.DeveloperType.str.lstrip()
dev_type_df = df.DeveloperType.str.replace('; ',';').str.get_dummies(sep=';')

for col in dev_type_df.columns: 
    print(col)
# Out:
# Data scientist
# Database administrator
# Desktop applications developer
# DevOps specialist
# Developer with a statistics or mathematics background
# Embedded applications/devices developer
# Graphic designer
# Graphics programming
# Machine learning specialist
# Mobile developer
# Other
# Quality assurance engineer
# Systems administrator
# Web developer

# %%
test_df = pd.melt(dev_type_df)
fig, ax = plt.subplots(figsize=(15,15))

g1 = sns.countplot(data=test_df.loc[test_df['value']!=0], y='variable'
              , order=test_df[test_df['value']!=0]['variable'].value_counts().index)

#g1.set(xticklabels=[])  # remove the tick labels
#g1.set(title='Exercise: Pulse by Time for Exercise Type')  # add a title
g1.set(ylabel=None)# remove the axis label
plt.yticks(fontsize=16)
plt.xticks(fontsize=14)
plt.ylabel(None)
plt.xlabel('Count',fontsize = 16);

# %%
df[df.DeveloperType.str.contains('Data scientist') | df.DeveloperType.str.contains('Machine learning')]
# Out:
#        Respondent            Professional               ProgramHobby  \
# 19             20  Professional developer  Yes, I program as a hobby
# 35             36  Professional developer  Yes, I program as a hobby
# 63             64  Professional developer                         No
# 82             83  Professional developer  Yes, I program as a hobby
# 91             92  Professional developer                  Yes, both
# ...           ...                     ...                        ...
# 51327       51328  Professional developer  Yes, I program as a hobby
# 51345       51346  Professional developer                         No
# 51353       51354  Professional developer                  Yes, both
# 51371       51372  Professional developer                         No
# 51386       51387  Professional developer                  Yes, both
#
#               Country      University                        EmploymentStatus  \
# 19             Greece              No                      Employed full-time
# 35              Italy              No                      Employed full-time
# 63     United Kingdom              No                      Employed full-time
# 82      United States              No                      Employed full-time
# 91            Germany              No  Not employed, and not looking for work
# ...               ...             ...                                     ...
# 51327       Australia  Yes, full-time                      Employed part-time
# 51345  United Kingdom              No                      Employed full-time
# 51353  American Samoa              No                      Employed full-time
# 51371     Netherlands              No                      Employed full-time
# 51386         Romania              No                      Employed full-time
#
#                                          FormalEducation  \
# 19                                       Doctoral degree
# 35                                       Master's degree
# 63                                       Master's degree
# 82                                     Bachelor's degree
# 91                                       Master's degree
# ...                                                  ...
# 51327                                   Secondary school
# 51345                                    Doctoral degree
# 51353                                    Doctoral degree
# 51371                                  Bachelor's degree
# 51386  Some college/university study without earning ...
#
#                                       MajorUndergrad  \
# 19                                 A natural science
# 35          Computer science or software engineering
# 63                                    Something else
# 82                      Fine arts or performing arts
# 91          Computer science or software engineering
# ...                                              ...
# 51327                                            NaN
# 51345  A non-computer-focused engineering discipline
# 51353                                 Something else
# 51371       Computer science or software engineering
# 51386                                 Something else
#
#                                               HomeRemote  \
# 19     Less than half the time, but at least one day ...
# 35                                                 Never
# 63                                 A few days each month
# 82                                                 Never
# 91                                                   NaN
# ...                                                  ...
# 51327                                              Never
# 51345                              A few days each month
# 51353                                   It's complicated
# 51371  All or almost all the time (I'm full-time remote)
# 51386                                   It's complicated
#
#                     CompanySize  ... StackOverflowMakeMoney  Gender  \
# 19      Fewer than 10 employees  ...      Strongly disagree    Male
# 35      Fewer than 10 employees  ...               Disagree    Male
# 63         100 to 499 employees  ...                    NaN   Other
# 82     10,000 or more employees  ...               Disagree    Male
# 91                          NaN  ...               Disagree    Male
# ...                         ...  ...                    ...     ...
# 51327        20 to 99 employees  ...      Strongly disagree    Male
# 51345      100 to 499 employees  ...               Disagree  Female
# 51353  10,000 or more employees  ...                    NaN   Other
# 51371   Fewer than 10 employees  ...               Disagree    Male
# 51386      100 to 499 employees  ...         Somewhat agree    Male
#
#       HighestEducationParents  \
# 19          A master's degree
# 35          A master's degree
# 63                        NaN
# 82        A bachelor's degree
# 91          A master's degree
# ...                       ...
# 51327   A professional degree
# 51345       A master's degree
# 51353            No education
# 51371     A bachelor's degree
# 51386             High school
#
#                                                     Race         SurveyLong  \
# 19                                   I prefer not to say              Agree
# 35                          White or of European descent     Somewhat agree
# 63                                                   NaN                NaN
# 82                          White or of European descent     Somewhat agree
# 91                          White or of European descent           Disagree
# ...                                                  ...                ...
# 51327                                         East Asian     Somewhat agree
# 51345                       White or of European descent     Somewhat agree
# 51353  Black or of African descent; East Asian; Hispa...  Strongly disagree
# 51371                       White or of European descent           Disagree
# 51386                       White or of European descent              Agree
#
#       QuestionsInteresting QuestionsConfusing  InterestedAnswers  \
# 19          Somewhat agree           Disagree     Somewhat agree
# 35                   Agree           Disagree     Strongly agree
# 63                     NaN                NaN                NaN
# 82                   Agree  Strongly disagree              Agree
# 91          Somewhat agree  Strongly disagree     Somewhat agree
# ...                    ...                ...                ...
# 51327                Agree  Strongly disagree     Strongly agree
# 51345                Agree           Disagree              Agree
# 51353       Strongly agree  Strongly disagree  Strongly disagree
# 51371                Agree  Strongly disagree              Agree
# 51386                Agree           Disagree     Somewhat agree
#
#              Salary  ExpectedSalary
# 19              NaN             NaN
# 35              NaN             NaN
# 63              NaN             NaN
# 82              NaN             NaN
# 91              NaN             NaN
# ...             ...             ...
# 51327           NaN             NaN
# 51345           NaN             NaN
# 51353           NaN             NaN
# 51371  74193.548387             NaN
# 51386           NaN             NaN
#
# [3595 rows x 154 columns]

# %%
df.loc[(df.Gender!='Male') & (df.Gender!='Female'),'Gender']='Other'

# %%
df.Country.value_counts()
fig, ax = plt.subplots(figsize=(15,15))
g1 = sns.countplot(data=df, hue ='Gender', y='Country', order = df.Country.value_counts().iloc[:20].index)
plt.title('Top 20 Countries from 2017 Stackoverflow Survey')
plt.legend(bbox_to_anchor=(1.1, 1.), loc='upper right', borderaxespad=0.);

# %%
DS_df = df[df.DeveloperType.str.contains('Data scientist') | df.DeveloperType.str.contains('Machine learning')]

# %%
DS_df.head()
# Out:
#     Respondent            Professional               ProgramHobby  \
# 19          20  Professional developer  Yes, I program as a hobby
# 35          36  Professional developer  Yes, I program as a hobby
# 63          64  Professional developer                         No
# 82          83  Professional developer  Yes, I program as a hobby
# 91          92  Professional developer                  Yes, both
#
#            Country University                        EmploymentStatus  \
# 19          Greece         No                      Employed full-time
# 35           Italy         No                      Employed full-time
# 63  United Kingdom         No                      Employed full-time
# 82   United States         No                      Employed full-time
# 91         Germany         No  Not employed, and not looking for work
#
#       FormalEducation                            MajorUndergrad  \
# 19    Doctoral degree                         A natural science
# 35    Master's degree  Computer science or software engineering
# 63    Master's degree                            Something else
# 82  Bachelor's degree              Fine arts or performing arts
# 91    Master's degree  Computer science or software engineering
#
#                                            HomeRemote  \
# 19  Less than half the time, but at least one day ...
# 35                                              Never
# 63                              A few days each month
# 82                                              Never
# 91                                                NaN
#
#                  CompanySize  ... StackOverflowMakeMoney Gender  \
# 19   Fewer than 10 employees  ...      Strongly disagree   Male
# 35   Fewer than 10 employees  ...               Disagree   Male
# 63      100 to 499 employees  ...                    NaN  Other
# 82  10,000 or more employees  ...               Disagree   Male
# 91                       NaN  ...               Disagree   Male
#
#    HighestEducationParents                          Race      SurveyLong  \
# 19       A master's degree           I prefer not to say           Agree
# 35       A master's degree  White or of European descent  Somewhat agree
# 63                     NaN                           NaN             NaN
# 82     A bachelor's degree  White or of European descent  Somewhat agree
# 91       A master's degree  White or of European descent        Disagree
#
#    QuestionsInteresting QuestionsConfusing InterestedAnswers  Salary  \
# 19       Somewhat agree           Disagree    Somewhat agree     NaN
# 35                Agree           Disagree    Strongly agree     NaN
# 63                  NaN                NaN               NaN     NaN
# 82                Agree  Strongly disagree             Agree     NaN
# 91       Somewhat agree  Strongly disagree    Somewhat agree     NaN
#
#     ExpectedSalary
# 19             NaN
# 35             NaN
# 63             NaN
# 82             NaN
# 91             NaN
#
# [5 rows x 154 columns]

# %%
fig, ax = plt.subplots(figsize=(15,15))
g1 = sns.countplot(data=DS_df, hue ='Gender', y='Country', order = DS_df.Country.value_counts().iloc[:20].index)
plt.title('Top 20 Countries from 2017 Stackoverflow Survey')
plt.legend(bbox_to_anchor=(1.1, 1.), loc='upper right', borderaxespad=0.);

# %%
DS_df.JobSatisfaction.hist()

# %%
desired_columns = ['Respondent', 'Professional', 'ProgramHobby', 'Country',
       'University', 'EmploymentStatus', 'FormalEducation',
       'MajorUndergrad', 'HomeRemote', 'CompanySize', 'CompanyType',
       'YearsProgram', 'YearsCodedJob', 'YearsCodedJobPast',
       'DeveloperType', 'WebDeveloperType', 'MobileDeveloperType',
       'NonDeveloperType', 'CareerSatisfaction', 'JobSatisfaction',
       #'ExCoderReturn', 'ExCoderNotForMe', 'ExCoderBalance',
       #'ExCoder10Years', 'ExCoderBelonged', 'ExCoderSkills',
       #'ExCoderWillNotCode', 'ExCoderActive', 'PronounceGIF',
       'ProblemSolving', 'BuildingThings', 'LearningNewTech',
       'BoringDetails', 'JobSecurity', 'DiversityImportant', 'AnnoyingUI',
       'FriendsDevelopers', 'RightWrongWay', 'UnderstandComputers',
       'SeriousWork', 'InvestTimeTools', 'WorkPayCare',
       'KinshipDevelopers', 'ChallengeMyself', 'CompetePeers',
       'ChangeWorld', 'JobSeekingStatus', 'HoursPerWeek', 'LastNewJob'.
       'AssessJobIndustry', 'AssessJobRole', 'AssessJobExp',
       'AssessJobDept', 'AssessJobTech', 'AssessJobProjects',
       'AssessJobCompensation', 'AssessJobOffice', 'AssessJobCommute',
       'AssessJobRemote', 'AssessJobLeaders', 'AssessJobProfDevel',
       'AssessJobDiversity', 'AssessJobProduct', 'AssessJobFinances',
       'ImportantBenefits','EducationImportant', 'EducationTypes',
       'SelfTaughtTypes','HaveWorkedLanguage', 'WantWorkLanguage',
       'HaveWorkedFramework', 'WantWorkFramework', 'HaveWorkedDatabase',
       'WantWorkDatabase', 'HaveWorkedPlatform', 'WantWorkPlatform',
        #'ClickyKeys', 'JobProfile', 'ResumePrompted',
       #'LearnedHiring', 'ImportantHiringAlgorithms',
       #'ImportantHiringTechExp', 'ImportantHiringCommunication',
       #'ImportantHiringOpenSource', 'ImportantHiringPMExp',
        'Gender','Race','Salary','ExpectedSalary']

# %%
#desired_columns = ['Respondent','Professional','Country','EmploymentStatus','FormalEducation','MajorUndergrad','HomeRemote',
                 # 'CareerSatisfaction','JobSatisfaction','Gender','Salary','ExpectedSalary']

# %%
new_df = df[desired_columns]

# %%
new_df.head()

# %%
new_df.Gender.unique()

# %%
new_df[(new_df.Gender =='Male') | (new_df.Gender=='Female') |(new_df.Gender=='Transgender') ].Gender.value_counts()

# %%
new_df.loc[((new_df.Gender !='Male') & (new_df.Gender!='Female')  & (new_df.Gender!='Transgender')),'Gender'] = 'Other'

# %%
# Check the Gender Distribution
new_df.Gender.value_counts()/new_df.shape[0]*100

# %%
def cat_rate(df,cat_col,cat_val,df_col):
    return (df[df[cat_col] == cat_val][df_col].value_counts())/df[df[cat_col] == cat_val].shape[0]*100

# %%
cat_rate(new_df,'Gender','Female','FormalEducation')

# %%
cat_rate(new_df,'Gender','Male','FormalEducation')

# %%
cat_rate(new_df,'Gender','Transgender','FormalEducation')

# %%
cat_rate(new_df,'Gender','Other','FormalEducation')

# %%
cat_rate(new_df,'Gender','Female','CareerSatisfaction')

# %%
cat_rate(new_df,'Gender','Male','CareerSatisfaction')

# %%
cat_rate(new_df,'Gender','Other','JobSatisfaction')

# %%
plt.hist(new_df[new_df.Gender=='Female'].JobSatisfaction, alpha = 1, color= 'g',density=True);
plt.hist(new_df[new_df.Gender=='Male'].JobSatisfaction, alpha = 0.7,density=True);

# %%
genders = ['Male','Female']
plt.hist([new_df.loc[new_df.Gender == x, 'JobSatisfaction'] for x in genders], label=genders,density=True);
plt.legend(genders);
plt.title('Histogram of Job Satisfaction for Men and Wemon');

# %%
sum(new_df[new_df.Gender=='Female']['JobSatisfaction'].isnull())/new_df[new_df.Gender=='Female']['JobSatisfaction'].shape[0]

# %%
df_dropna = new_df.dropna(subset=['JobSatisfaction'],axis=0)

# %%
data_to_plot = [df_dropna[df_dropna.Gender=='Female']['JobSatisfaction'], (df_dropna[df_dropna.Gender=='Male']['JobSatisfaction'])]

# Create a figure instance
fig = plt.figure()
# Create an axes instance
ax = fig.add_subplot(111)
# Create the boxplot
bp = ax.boxplot(data_to_plot,showmeans=True)

ax.set_xticklabels(['Female','Male']);

# %%
np.sum(new_df[new_df.Gender=='Male'].Salary.isnull())/new_df[new_df.Gender=='Male'].shape[0]

# %%
np.sum(new_df[new_df.Gender=='Female'].Salary.isnull())/new_df[new_df.Gender=='Female'].shape[0]

# %%
# Replace null Salary with min values
fill_mean = lambda col: col.fillna(col.mean()) # Mean function

fill_df = drop_sal_df.apply(fill_mean, axis=0) #Fill all missing values with the mean of the column.

# test look
fill_df.head()

# %%
# Number of Countries participated in the survey
(new_df.Country.nunique())

# %%
(np.sum(new_df.isnull())/np.sum(new_df.shape[0])>0.5)
